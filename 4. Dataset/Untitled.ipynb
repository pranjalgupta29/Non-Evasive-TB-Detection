# %%
import pandas as pd

# %%
dataset = pd.read_csv("CAPSTONE DATABASE/final.csv")

# %%
dataset.head()
# Out:
#    5.78026095  2.76847791  5.41724501  4.84268438  0.69999374  0.34205703  \
# 0    5.780394    2.768310    5.417510    4.842808    0.699963    0.342061
# 1    5.780598    2.768239    5.417487    4.843149    0.699919    0.342055
# 2    5.780843    2.768181    5.417957    4.843350    0.699914    0.342061
# 3    5.780524    2.768465    5.417796    4.842823    0.699921    0.342052
# 4    5.780223    2.768439    5.417750    4.842816    0.699892    0.342051
#
#    4.46347628  2.49279236  1.60401009  1.83542371  ...  2.13828748  \
# 0    4.463811    2.492679    1.603980    1.835507  ...    2.138226
# 1    4.463644    2.492835    1.603877    1.835508  ...    2.138337
# 2    4.463500    2.492772    1.603925    1.835461  ...    2.138287
# 3    4.463093    2.492698    1.603979    1.835478  ...    2.138178
# 4    4.463409    2.492579    1.603897    1.835448  ...    2.138303
#
#    0.57668507  1.96571404  0.27724985  0.89456408  1.01918865  2.76798463  \
# ...

# %%
dataset.tail()
# Out:
#        5.78026095  2.76847791  5.41724501  4.84268438  0.69999374  0.34205703  \
# 11379    5.931808    2.828546    5.544698    4.964612    0.712117    0.355185
# 11380    5.931038    2.828375    5.544332    4.964058    0.711894    0.355172
# 11381    5.931038    2.828590    5.544163    4.964574    0.711739    0.355149
# 11382    5.931013    2.828444    5.544513    4.964635    0.711742    0.355123
# 11383    5.931363    2.828597    5.544974    4.964828    0.711780    0.355129
#
#        4.46347628  2.49279236  1.60401009  1.83542371  ...  2.13828748  \
# 11379    4.538470    2.492104    1.639853    1.849116  ...    2.222816
# 11380    4.538206    2.492068    1.639714    1.849077  ...    2.222749
# 11381    4.538000    2.492056    1.639837    1.849133  ...    2.222710
# 11382    4.538102    2.491879    1.639779    1.849193  ...    2.222737
# 11383    4.538416    2.491952    1.639942    1.849090  ...    2.222776
#
# ...

# %%
tbneg = pd.read_csv("CAPSTONE DATABASE/TB NEG/Rectified/HC001.csv") #CAPSTONE DATABASE/TB NEG/HC001.csv

# %%
tbneg['S1'].mean()
# Out:
# 5.7821332748634795

# %%
print(tbneg.keys())
# Out:
# Index(['Time', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Ambient Temp [C]',
#        'Therm1 [volts]', 'Battery Raw Reading', 'Flag', 'S1', 'S2', 'S3', 'S4',
#        'S5', 'S6', 'S7', 'S8', 'S9', 'S10', 'S11', 'S12', 'S13', 'S14', 'S15',
#        'S16', 'S17', 'S18', 'S19', 'S20', 'S21', 'S22', 'S23', 'S24', 'S25',
#        'S26', 'S27', 'S28', 'S29', 'S30', 'S31', 'S32'],
#       dtype='object')

# %%
tbneg.drop(tbneg.columns[[0,1,2,3]], axis=1, inplace=True)

# %%
tbneg.head()
# Out:
#    Ambient Temp [C]  Therm1 [volts]  Battery Raw Reading  Flag        S1  \
# 0              35.0        1.211548               4095.0     0  5.781849
# 1              35.0        1.212158               4095.0     0  5.780850
# 2              35.0        1.212769               4095.0     0  5.781212
# 3              35.0        1.210938               4095.0     0  5.780809
# 4              35.0        1.212158               4095.0     0  5.781110
#
#          S2        S3        S4        S5        S6  ...       S23       S24  \
# 0  2.768626  5.419640  4.843829  0.700669  0.342188  ...  0.758844  2.138055
# 1  2.768654  5.419576  4.843322  0.700730  0.342195  ...  0.758828  2.138179
# 2  2.768640  5.419447  4.843226  0.700724  0.342182  ...  0.758853  2.138109
# 3  2.768572  5.419293  4.843789  0.700709  0.342185  ...  0.758847  2.138149
# 4  2.768540  5.419345  4.844029  0.700727  0.342218  ...  0.758862  2.138098
#
# ...

# %%
tbneg.drop(tbneg.columns[[0,1,2,3]], axis=1, inplace=True)

# %%
tbneg.head()
# Out:
#          S1        S2        S3        S4        S5        S6        S7  \
# 0  5.781849  2.768626  5.419640  4.843829  0.700669  0.342188  4.463546
# 1  5.780850  2.768654  5.419576  4.843322  0.700730  0.342195  4.463808
# 2  5.781212  2.768640  5.419447  4.843226  0.700724  0.342182  4.463772
# 3  5.780809  2.768572  5.419293  4.843789  0.700709  0.342185  4.463486
# 4  5.781110  2.768540  5.419345  4.844029  0.700727  0.342218  4.463541
#
#          S8        S9       S10  ...       S23       S24       S25       S26  \
# 0  2.492374  1.604312  1.835539  ...  0.758844  2.138055  0.576709  1.965907
# 1  2.492462  1.604390  1.835551  ...  0.758828  2.138179  0.576700  1.966035
# 2  2.492448  1.604399  1.835552  ...  0.758853  2.138109  0.576699  1.965938
# 3  2.492451  1.604394  1.835537  ...  0.758847  2.138149  0.576701  1.965759
# 4  2.492401  1.604372  1.835609  ...  0.758862  2.138098  0.576699  1.965818
#
#         S27       S28       S29       S30       S31       S32
# ...

# %%
d1 = tbneg.mean(axis = 0)

# %%
d1
# Out:
# S1     5.782133
# S2     2.769264
# S3     5.424219
# S4     4.843676
# S5     0.704096
# S6     0.342771
# S7     4.464379
# S8     2.492446
# S9     1.606073
# S10    1.835967
# S11    1.326801
# S12    0.557694
# S13    0.754116
# S14    0.518615
# S15    1.254236
# S16    1.175101
# S17    0.813150
# S18    0.779737
# S19    0.747444
# S20    0.909272
# S21    0.514530
# S22    0.595269
# S23    0.760718
# S24    2.138571
# S25    0.576764
# S26    1.967537
# S27    0.277270
# S28    0.895345
# S29    1.020238
# S30    2.770343
# S31    0.466101
# S32    0.477085
# dtype: float64

# %%
d1['S1']
# Out:
# 5.7821332748634795

# %%
df1 = pd.DataFrame(d1)

# %%
df1
# Out:
#             0
# S1   5.782133
# S2   2.769264
# S3   5.424219
# S4   4.843676
# S5   0.704096
# S6   0.342771
# S7   4.464379
# S8   2.492446
# S9   1.606073
# S10  1.835967
# S11  1.326801
# S12  0.557694
# S13  0.754116
# S14  0.518615
# S15  1.254236
# S16  1.175101
# S17  0.813150
# S18  0.779737
# S19  0.747444
# S20  0.909272
# S21  0.514530
# S22  0.595269
# S23  0.760718
# S24  2.138571
# S25  0.576764
# S26  1.967537
# S27  0.277270
# S28  0.895345
# S29  1.020238
# S30  2.770343
# S31  0.466101
# S32  0.477085

# %%
df1.pivot(columns=list(df1.keys()), values=list(df1.values))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-ca90c7f6936a> in <module>
# ----> 1 df1.pivot(columns=list(df1.keys()), values=list(df1.values))
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    6877         from pandas.core.reshape.pivot import pivot
#    6878
# -> 6879         return pivot(self, index=index, columns=columns, values=values)
#    6880
#    6881     _shared_docs[
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     455             values = cast(Sequence[Label], values)
#     456             indexed = data._constructor(
# --> 457                 data[values]._values, index=index, columns=values
#     458             )
#     459         else:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
# ...

# %%
df1.pivot(columns = 'S1','S2','S3','S4','S5','S6','S7','S8','S9','S10','S11','S12','S13','S14','S15','S16','S17','S18','S19','S20','S21','S22','S23','S24','S25','S26','S27','S28','S29','S30','S31','S32')
# Out:
#   File "<ipython-input-55-83c9541eba78>", line 1
#     df1.pivot(columns = 'S1','S2','S3','S4','S5','S6','S7','S8','S9','S10','S11','S12','S13','S14','S15','S16','S17','S18','S19','S20','S21','S22','S23','S24','S25','S26','S27','S28','S29','S30','S31','S32')
#                              ^
# SyntaxError: positional argument follows keyword argument

# %%
list(d1.keys())
# Out:
# ['S1',
#  'S2',
#  'S3',
#  'S4',
#  'S5',
#  'S6',
#  'S7',
#  'S8',
#  'S9',
#  'S10',
#  'S11',
#  'S12',
#  'S13',
#  'S14',
#  'S15',
#  'S16',
#  'S17',
#  'S18',
#  'S19',
#  'S20',
#  'S21',
#  'S22',
#  'S23',
#  'S24',
#  'S25',
#  'S26',
#  'S27',
#  'S28',
#  'S29',
#  'S30',
#  'S31',
#  'S32']
